# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\VISHAL\OneDrive\Desktop\DSBDA Dataset\dataset_Facebook.csv",sep = ";")
df.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
subset1  = df.iloc[:9,[1,2,3]]
subset1
# Out:
#      Type  Category  Post Month
# 0   Photo         2          12
# 1  Status         2          12
# 2   Photo         3          12
# 3   Photo         2          12
# 4   Photo         2          12
# 5  Status         2          12
# 6   Photo         3          12
# 7   Photo         3          12
# 8  Status         2          12

# %%
subset2  = df.iloc[9:19,[1,2,3]]
subset2
# Out:
#       Type  Category  Post Month
# 9    Photo         3          12
# 10  Status         2          12
# 11   Photo         2          12
# 12   Photo         2          12
# 13   Photo         2          12
# 14   Photo         2          12
# 15  Status         2          12
# 16   Photo         3          12
# 17   Photo         1          12
# 18  Status         3          12

# %%
subset3  = df.iloc[19:29,[1,2,3]]
subset3
# Out:
#       Type  Category  Post Month
# 19   Photo         3          12
# 20   Photo         2          12
# 21   Photo         1          12
# 22    Link         1          12
# 23   Photo         3          12
# 24  Status         2          12
# 25  Status         2          12
# 26  Status         2          12
# 27   Photo         3          12
# 28   Photo         2          12

# %%
mergedDF = pd.concat([subset1,subset2,subset3])
mergedDF
# Out:
#       Type  Category  Post Month
# 0    Photo         2          12
# 1   Status         2          12
# 2    Photo         3          12
# 3    Photo         2          12
# 4    Photo         2          12
# 5   Status         2          12
# 6    Photo         3          12
# 7    Photo         3          12
# 8   Status         2          12
# 9    Photo         3          12
# 10  Status         2          12
# 11   Photo         2          12
# 12   Photo         2          12
# 13   Photo         2          12
# 14   Photo         2          12
# 15  Status         2          12
# 16   Photo         3          12
# 17   Photo         1          12
# 18  Status         3          12
# 19   Photo         3          12
# 20   Photo         2          12
# 21   Photo         1          12
# 22    Link         1          12
# 23   Photo         3          12
# 24  Status         2          12
# 25  Status         2          12
# 26  Status         2          12
# ...

# %%
sortedDF = mergedDF.sort_values(by = 'Category')

# %%
sortedDF
# Out:
#       Type  Category  Post Month
# 22    Link         1          12
# 21   Photo         1          12
# 17   Photo         1          12
# 0    Photo         2          12
# 26  Status         2          12
# 25  Status         2          12
# 24  Status         2          12
# 20   Photo         2          12
# 15  Status         2          12
# 13   Photo         2          12
# 12   Photo         2          12
# 14   Photo         2          12
# 10  Status         2          12
# 1   Status         2          12
# 3    Photo         2          12
# 4    Photo         2          12
# 5   Status         2          12
# 11   Photo         2          12
# 28   Photo         2          12
# 8   Status         2          12
# 19   Photo         3          12
# 7    Photo         3          12
# 16   Photo         3          12
# 23   Photo         3          12
# 27   Photo         3          12
# 2    Photo         3          12
# 9    Photo         3          12
# ...

# %%
sortedDF1 = df.sort_values('like',ascending=0)

# %%
sortedDF1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
mergedDF.transpose()
# Out:
#                0       1      2      3      4       5      6      7       8   \
# Type        Photo  Status  Photo  Photo  Photo  Status  Photo  Photo  Status
# Category        2       2      3      2      2       2      3      3       2
# Post Month     12      12     12     12     12      12     12     12      12
#
#                9   ...     19     20     21    22     23      24      25  \
# Type        Photo  ...  Photo  Photo  Photo  Link  Photo  Status  Status
# Category        3  ...      3      2      1     1      3       2       2
# Post Month     12  ...     12     12     12    12     12      12      12
#
#                 26     27     28
# Type        Status  Photo  Photo
# Category         2      3      2
# Post Month      12     12     12
#
# [3 rows x 29 columns]

# %%
df.shape
# Out:
# (500, 19)

# %%
reshapedDF = pd.pivot_table(df,index=['Type','Category'])

# %%
reshapedDF
# Out:
#                  Lifetime Engaged Users  \
# Type   Category
# Link   1                     357.850000
#        2                     103.000000
#        3                     282.000000
# Photo  1                     852.227027
#        2                     727.208791
#        3                     833.553333
# Status 1                    2074.666667
#        2                    2150.210526
#        3                     969.500000
# Video  1                    1707.000000
#
#                  Lifetime People who have liked your Page and engaged with your post  \
# Type   Category
# Link   1                                                214.050000
#        2                                                 92.000000
#        3                                                259.000000
# Photo  1                                                522.508108
#        2                                                446.604396
# ...
